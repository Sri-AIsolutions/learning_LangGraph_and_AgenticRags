# %%
print("""
 We can think of this os router, where the chat model(llm) routes
       between a direct response or a tool call based upon the user input
      
      """)
# Out:
#  We can think of this os router, where the chat model(llm) routes
#        between a direct response or a tool call based upon the user input

# %%
print("""
This is a simple example of agent, WHERE THE LLM IS DIRECTING CONTROL FLOW 
      EITHER BY CALLING A TOOL OR JUST RESPONDING DIRECTLY
      """)
# Out:
# This is a simple example of agent, WHERE THE LLM IS DIRECTING CONTROL FLOW
#       EITHER BY CALLING A TOOL OR JUST RESPONDING DIRECTLY
