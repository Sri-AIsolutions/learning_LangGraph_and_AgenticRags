# %% [markdown]
# ->How to use chat messages (Human message, AI message) as graph state
#
# ->using chat models in nodes
#
# ->binding tools to llm in chat model
#
# ->execution of the tool calls in graph nodes

# %%
from dotenv import load_dotenv
load_dotenv()

import os
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# MEssages:
# there are different types of messages like AImessage, Human message, System message, tool message
#
# every message has these important components:
#
# 1->content---content if the message
#
# 2->name---specific name of the author
#
# 3->response_metadata

# %%
from langchain_core.messages import AIMessage,HumanMessage
#creating custom messages manually---->these basically happen during the chat (but here we r just creating it manually for better understanding)
messages=[AIMessage(content=f"heyy! tell me what do u want to learn today!!!",name="LLMModel")]
messages.append(HumanMessage(content=f"I want to master RAGs and Agentic AI",name="sri"))
messages.append(AIMessage(content=f"Do u want to start with Agent Archietecture or Langchain Basics",name="LLMModel"))

for n in messages:
    n.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: LLMModel
#
# heyy! tell me what do u want to learn today!!!
# ================================ Human Message =================================
# Name: sri
#
# I want to master RAGs and Agentic AI
# ================================== Ai Message ==================================
# Name: LLMModel
#
# Do u want to start with Agent Archietecture or Langchain Basics

# %% [markdown]
# while building the graph --we make sure messages are appended in its stateschema automatically
#
# NOTE: these automatic appending part is completely taken care by reducers in langgraphs

# %% [markdown]
# PART2-CHAT MODELS

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-5-nano")
llm
# Out:
# ChatOpenAI(profile={'max_input_tokens': 272000, 'max_output_tokens': 128000, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000002933325A0D0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002933325A490>, root_client=<openai.OpenAI object at 0x0000029333259E50>, root_async_client=<openai.AsyncOpenAI object at 0x000002933325A210>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
llm.invoke("")
